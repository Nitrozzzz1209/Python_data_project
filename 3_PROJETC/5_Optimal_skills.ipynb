# %% [markdown]
# What is the most optimal skill to learn for Data Analysts?

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

df_DA_US_exploded = df_DA_US.explode('job_skills')

df_DA_US_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
# using df_DA find the count of skills and also the median salary for each skill
df_DA_skills = df_DA_US_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_US)  # Find count of Data Analyst jobs in US with salary info

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

df_DA_skills = df_DA_skills[df_DA_skills['skill_count'] > 0]

df_DA_skills
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                2508        91000.0      57.655172
# excel              1808        84392.0      41.563218
# python             1431        97500.0      32.896552
# tableau            1364        92875.0      31.356322
# sas                 926        90000.0      21.287356
# ...                 ...            ...            ...
# theano                1       100000.0       0.022989
# typescript            1        65000.0       0.022989
# vmware                1       147500.0       0.022989
# vue                   1        65000.0       0.022989
# wrike                 1        75000.0       0.022989
#
# [170 rows x 3 columns]

# %%
skill_limit = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_limit]

# %%
plt.scatter(df_DA_skills_high_demand['skill_percent'], df_DA_skills_high_demand['median_salary'])
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Salary ($USD)')  # Assuming this is the label you want for y-axis
plt.title('Most Optimal Skills for Data Analysts in the US')

# Get current axes, set limits, and format axes
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))  # Example formatting y-axis

# Add labels to points and collect them in a list
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], " " + txt))

# Adjust text to avoid overlap and add arrows
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 16
#      13     texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], " " + txt))
#      15 # Adjust text to avoid overlap and add arrows
# ---> 16 adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))
#      18 plt.show()
#
# NameError: name 'adjust_text' is not defined

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['alteryx',
#   'power bi',
#   'sharepoint',
#   'sas',
#   'powerpoint',
#   'ms access',
#   'cognos',
#   'esquisse',
#   'visio',
#   'outlook',
#   'powerbi',
#   'microstrategy',
#   'word',
#   'qlik',
#   'spreadsheet',
#   'sap',
#   'tableau',
#   'dax',
#   'datarobot',
#   'msaccess',
#   'splunk',
#   'ssis',
#   'spss',
#   'ssrs',
#   'excel',
#   'sheets',
#   'nuix',
#   'looker'],
#  'programming': ['mongo',
#   'visualbasic',
#   'c',
#   'no-sql',
#   'java',
#   'nosql',
#   'visual basic',
#   'go',
#   'julia',
#   'ocaml',
#   'c#',
#   'sql',
#   'sas',
#   'groovy',
#   'python',
#   'matlab',
#   'golang',
#   'crystal',
#   'dart',
#   'shell',
#   'objective-c',
#   'rust',
#   'ruby',
#   'sass',
#   'fortran',
#   't-sql',
#   'vba',
#   'vb.net',
#   'javascript',
#   'pascal',
#   'lua',
#   'elixir',
#   'scala',
#   'assembly',
#   'c++',
#   'kotlin',
#   'perl',
#   'lisp',
#   'mongodb',
#   'bash',
#   'html',
#   'typescript',
#   'haskell',
#   'css',
#   'php',
#   'erlang',
#   'r',
#   'swift',
#   'solidity',
#   'apl',
#   'cobol',
#   'delphi',
#   'f#',
#   'clojure',
#   'powershell'],
#  'cloud': ['azure',
#   'firebase',
#   'digitalocean',
#   'redshift',
#   'bigquery',
#   'ovh',
#   'openstack',
#   'databricks',
#   'aws',
#   'watson',
#   'aurora',
#   'oracle',
#   'vmware',
#   'snowflake',
#   'ibm cloud',
#   'linode',
#   'gcp',
#   'colocation',
#   'heroku'],
#  'libraries': ['flutter',
#   'numpy',
#   'tidyverse',
#   'seaborn',
#   'mlr',
#   'graphql',
#   'react',
#   'ionic',
#   'dlib',
#   'airflow',
#   'nltk',
#   'electron',
#   'jupyter',
#   'theano',
#   'pandas',
#   'xamarin',
#   'mxnet',
#   'cordova',
#   'spring',
#   'selenium',
#   'huggingface',
#   'keras',
#   'matplotlib',
#   'gdpr',
#   'dplyr',
#   'opencv',
#   'shogun',
#   'scikit-learn',
#   'kafka',
#   'mlpack',
#   'plotly',
#   'tidyr',
#   'gtx',
#   'chainer',
#   'tensorflow',
#   'spark',
#   'pyspark',
#   'pytorch',
#   'hugging face',
#   'ggplot2',
#   'hadoop',
#   'rshiny',
#   'qt',
#   'capacitor'],
#  'other': ['ansible',
#   'gitlab',
#   'docker',
#   'npm',
#   'pulumi',
#   'unreal',
#   'homebrew',
#   'terraform',
#   'atlassian',
#   'terminal',
#   'flow',
#   'github',
#   'kubernetes',
#   'svn',
#   'git',
#   'puppet',
#   'codecommit',
#   'bitbucket',
#   'jenkins',
#   'chef',
#   'unity',
#   'yarn'],
#  'databases': ['dynamodb',
#   'sqlserver',
#   'firebase',
#   'couchdb',
#   'sql server',
#   'postgresql',
#   'neo4j',
#   'mongodb',
#   'redis',
#   'db2',
#   'firestore',
#   'elasticsearch',
#   'mariadb',
#   'cassandra',
#   'couchbase',
#   'sqlite',
#   'mysql'],
#  'os': ['kali',
#   'centos',
#   'windows',
#   'fedora',
#   'suse',
#   'macos',
#   'linux',
#   'ubuntu',
#   'arch',
#   'wsl',
#   'debian',
#   'redhat',
#   'unix'],
#  'async': ['notion',
#   'airtable',
#   'clickup',
#   'smartsheet',
#   'confluence',
#   'wrike',
#   'workfront',
#   'microsoft lists',
#   'wimi',
#   'planner',
#   'asana',
#   'monday.com',
#   'dingtalk',
#   'trello',
#   'jira'],
#  'webframeworks': ['svelte',
#   'next.js',
#   'fastify',
#   'django',
#   'angular.js',
#   'vue.js',
#   'play framework',
#   'ruby on rails',
#   'asp.net',
#   'rubyon rails',
#   'express',
#   'vue',
#   'node',
#   'gatsby',
#   'deno',
#   'nuxt.js',
#   'ember.js',
#   'ruby',
#   'fastapi',
#   'node.js',
#   'asp.netcore',
#   'jquery',
#   'flask',
#   'symfony',
#   'angular',
#   'react.js',
#   'blazor',
#   'drupal',
#   'asp.net core',
#   'laravel',
#   'phoenix'],
#  'sync': ['slack',
#   'wire',
#   'webex',
#   'rocketchat',
#   'zoom',
#   'mattermost',
#   'unify',
#   'google chat',
#   'twilio',
#   'symphony',
#   'microsoft teams',
#   'ringcentral']}

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology           skills
# 0   analyst_tools          alteryx
# 0   analyst_tools         power bi
# 0   analyst_tools       sharepoint
# 0   analyst_tools              sas
# 0   analyst_tools       powerpoint
# ..            ...              ...
# 9            sync      google chat
# 9            sync           twilio
# 9            sync         symphony
# 9            sync  microsoft teams
# 9            sync      ringcentral
#
# [256 rows x 2 columns]

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#      skill_count  median_salary  skill_percent     technology      skills
# 0           2508        91000.0      57.655172    programming         sql
# 1           1808        84392.0      41.563218  analyst_tools       excel
# 2           1431        97500.0      32.896552    programming      python
# 3           1364        92875.0      31.356322  analyst_tools     tableau
# 4            926        90000.0      21.287356  analyst_tools         sas
# ..           ...            ...            ...            ...         ...
# 169            1       100000.0       0.022989      libraries      theano
# 170            1        65000.0       0.022989    programming  typescript
# 171            1       147500.0       0.022989          cloud      vmware
# 172            1        65000.0       0.022989  webframeworks         vue
# 173            1        75000.0       0.022989          async       wrike
#
# [174 rows x 5 columns]

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_limit]

# %%
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')
plt.legend(title='Technology')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot 
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 17
#      14     texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))
#      16 # Adjust text to avoid overlap
# ---> 17 adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))
#      19 # Set axis labels, title, and legend
#      20 plt.xlabel('Percent of Data Analyst Jobs')
#
# NameError: name 'adjust_text' is not defined
